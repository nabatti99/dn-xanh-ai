# %% [markdown]
# # Import the Required Libraries

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Household Waste Classifiers"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Household Waste Classifiers

# %%
# %rm -rf images

# %%
# !unzip -q archive.zip
# Out:
# replace README.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %%
# Imports
import torchvision.transforms.functional
from PIL import Image
from torch.utils.data import Dataset
from torchvision.transforms import v2
from torch.utils.data import DataLoader
import torch
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim

import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import mobilenet_v3_small
from torchvision.models.feature_extraction import (
    create_feature_extractor,
    get_graph_node_names,
)
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Imports
# ----> 2 import torchvision.transforms.functional
#       3 from PIL import Image
#       4 from torch.utils.data import Dataset
#
# ModuleNotFoundError: No module named 'torchvision'

# %% [markdown]
# # Prepare Custom Dataset and DataLoaders

# %%
# Prepare Custom Dataset Class
class WasteDataset(Dataset):
    def __init__(self, root_dir, split, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.image_paths = []
        self.labels = []

        for i, class_name in enumerate(self.classes):
            class_dir = os.path.join(root_dir, class_name)
            for subfolder in ["default", "real_world"]:
                subfolder_dir = os.path.join(class_dir, subfolder)
                image_names = os.listdir(subfolder_dir)
                random.shuffle(image_names)

                if split == "train":
                    image_names = image_names[: int(0.6 * len(image_names))]
                elif split == "val":
                    image_names = image_names[
                        int(0.6 * len(image_names)) : int(0.8 * len(image_names))
                    ]
                else:  # split == 'test'
                    image_names = image_names[int(0.8 * len(image_names)) :]

                for image_name in image_names:
                    self.image_paths.append(os.path.join(subfolder_dir, image_name))
                    self.labels.append(i)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        image_path = self.image_paths[index]
        label = self.labels[index]
        image = Image.open(image_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        data = {"image": image, "label": label}
        return data


# Prepare datasets and dataloaders

train_pil_transform = v2.Compose(
    [
        v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.2),
        v2.RandomAffine(
            degrees=5,
            translate=(0.1, 0.1),
            scale=(0.8, 1.3),
            interpolation=torchvision.transforms.InterpolationMode.BILINEAR,
        ),
        v2.Resize(size=(256, 256)),
        v2.GaussianBlur(kernel_size=(7, 13), sigma=(0.1, 0.2)),
        v2.PILToTensor(),
        v2.ToDtype(torch.float32),
        v2.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ]
)

val_pil_transform = v2.Compose(
    [
        v2.Resize(size=(256, 256)),
        v2.PILToTensor(),
        v2.ToDtype(torch.float32),
        v2.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ]
)

test_pil_transform = v2.Compose(
    [
        v2.Resize(size=(256, 256)),
        v2.PILToTensor(),
        v2.ToDtype(torch.float32),
        v2.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ]
)


data_transforms = {
    "train": train_pil_transform,
    "val": val_pil_transform,
    "test": test_pil_transform,
}

train_dataset = WasteDataset("images/images", "train", data_transforms["train"])
val_dataset = WasteDataset("images/images", "val", data_transforms["val"])
test_dataset = WasteDataset("images/images", "", data_transforms["test"])


image_datasets = {"train": train_dataset, "val": val_dataset, "test": test_dataset}

class_names = train_dataset.classes
dataset_sizes = {x: len(image_datasets[x]) for x in ["train", "val"]}
batch_size = 16

train_data_loader = DataLoader(
    train_dataset, batch_size, True, num_workers=0, pin_memory=True
)
val_data_loader = DataLoader(
    val_dataset, batch_size, False, num_workers=0, pin_memory=True
)
test_data_loader = DataLoader(test_dataset, batch_size, True)

data_loaders = {
    "train": train_data_loader,
    "val": val_data_loader,
    "test": test_data_loader,
}

# %% [markdown]
# # Visualize Images

# %%
def visualize_batch(batch, classes, dataset_type):
    # initialize a figure
    fig = plt.figure("{} batch".format(dataset_type), figsize=(batch_size, batch_size))
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    # loop over the batch size
    for i in range(0, batch_size):
        # create a subplot with 4x8
        ax = plt.subplot(4, 4, i + 1)
        # grab the image, convert it from channels first ordering to
        # channels last ordering, and scale the raw pixel intensities
        # to the range [0, 255]
        image = batch["image"][i].cpu().numpy()
        image = image.transpose((1, 2, 0))
        image = std * image + mean
        image = image.astype("uint8")
        # grab the label id and get the label from the classes list
        idx = batch["label"][i]
        label = classes[idx]
        # show the image along with the label
        plt.imshow(image)
        plt.title(label)
        plt.axis("off")
    # show the plot
    plt.tight_layout()
    plt.show()


# visualize train data
train_batch = next(iter(data_loaders["train"]))
visualize_batch(train_batch, class_names, "train")

# %% [markdown]
# # Custom Waste Classification Model

# %%
class WasteClassificationModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.mobnet = mobilenet_v3_small(
            weights=torchvision.models.MobileNet_V3_Small_Weights.IMAGENET1K_V1
        )
        train_nodes, eval_nodes = get_graph_node_names(self.mobnet)
        self.feature_extraction = create_feature_extractor(
            self.mobnet, return_nodes={"features.12": "mob_feature"}
        )
        self.conv1 = nn.Conv2d(576, 300, 3)
        # self.conv2 = nn.Conv2d(300,150, 3)
        self.fc1 = nn.Linear(10800, 30)
        # self.fc2 = nn.Linear(1000, 30)
        self.dr = nn.Dropout()

    def forward(self, x):
        feature_layer = self.feature_extraction(x)["mob_feature"]
        x = F.relu(self.conv1(feature_layer))
        # x = F.relu(self.conv2(x))
        x = x.flatten(start_dim=1)
        x = self.dr(x)
        # x = F.relu(self.fc1(x))
        # x = F.relu(self.fc2(x))
        output = self.fc1(x)
        return output

# %% [markdown]
# # Model Training

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using Device {device}")

# Prepare Criterion and Optimizer
model = WasteClassificationModel()
model = model.to(device)
criterian = nn.CrossEntropyLoss()
model_optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50

best_acc = {"train": -1000, "val": -1000}
best_loss = {"train": 1000, "val": 1000}

best_accuracy_model_path = {
    "train": os.path.join("models", "train_acc_best.pt"),
    "val": os.path.join("models", "val_acc_best.pt"),
}
best_loss_model_path = {
    "train": os.path.join("models", "train_loss_best.pt"),
    "val": os.path.join("models", "val_loss_best.pt"),
}

train_losses = []
val_losses = []

train_accs = []
val_accs = []

for epoch in range(num_epochs):

    print(f"Epoch {epoch}/{num_epochs - 1}")
    print("-" * 10)

    for phase in ["train", "val"]:
        if phase == "train":
            model.train()
        else:
            model.eval()

        running_loss = 0.0
        running_corrects = 0.0

        for idx, data in enumerate(data_loaders[phase]):

            inputs, labels = data["image"].to(device), data["label"].to(device)

            model_optimizer.zero_grad()

            with torch.set_grad_enabled(phase == "train"):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterian(outputs, labels)

                if phase == "train":
                    loss.backward()
                    model_optimizer.step()

            ## statitics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # if phase=="train":
        #     scheduler.step()

        epoch_loss = running_loss / dataset_sizes[phase]
        if phase == "train":
            train_losses.append(epoch_loss)
        else:
            val_losses.append(epoch_loss)

        epoch_acc = running_corrects / dataset_sizes[phase]
        epoch_acc = epoch_acc.cpu().numpy()[0]
        if phase == "train":
            train_accs.append(epoch_acc)
        else:
            val_accs.append(epoch_acc)

        print(f"{phase} Loss : {epoch_loss:.4f} Acc: {epoch_acc:.4f}")

        # deep copy the model
        if epoch_acc > best_acc[phase]:
            best_acc[phase] = epoch_acc
            torch.save(
                {
                    "epoch": idx,
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": model_optimizer.state_dict(),
                    "loss": running_loss,
                },
                best_accuracy_model_path[phase],
            )

        if epoch_loss < best_loss[phase]:
            best_loss[phase] = epoch_loss
            torch.save(
                {
                    "epoch": idx,
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": model_optimizer.state_dict(),
                    "loss": running_loss,
                },
                best_loss_model_path[phase],
            )
# Out:
# Using Device cuda:0
# Epoch 0/49
# ----------
# train Loss : 2.2884 Acc: 0.3649
# val Loss : 1.6353 Acc: 0.5223
# Epoch 1/49
# ----------
# train Loss : 1.8281 Acc: 0.4894
# val Loss : 1.4499 Acc: 0.5797
# Epoch 2/49
# ----------
# train Loss : 1.6559 Acc: 0.5372
# val Loss : 1.2264 Acc: 0.6413
# Epoch 3/49
# ----------
# train Loss : 1.5067 Acc: 0.5728
# val Loss : 1.4101 Acc: 0.5970
# Epoch 4/49
# ----------
# train Loss : 1.4081 Acc: 0.5977
# val Loss : 1.0787 Acc: 0.6947
# Epoch 5/49
# ----------
# train Loss : 1.3668 Acc: 0.6063
# val Loss : 1.0073 Acc: 0.7060
# Epoch 6/49
# ----------
# train Loss : 1.2633 Acc: 0.6366
# val Loss : 1.0062 Acc: 0.7237
# Epoch 7/49
# ----------
# train Loss : 1.2694 Acc: 0.6369
# val Loss : 0.9817 Acc: 0.7273
# Epoch 8/49
# ----------
# train Loss : 1.2242 Acc: 0.6504
# val Loss : 0.9443 Acc: 0.7230
# Epoch 9/49
# ----------
# train Loss : 1.1901 Acc: 0.6687
# val Loss : 0.8876 Acc: 0.7483
# Epoch 10/49
# ----------
# train Loss : 1.1359 Acc: 0.6726
# val Loss : 0.9730 Acc: 0.7220
# Epoch 11/49
# ----------
# train Loss : 1.1174 Acc: 0.6837
# val Loss : 0.8681 Acc: 0.7617
# Epoch 12/49
# ----------
# train Loss : 1.0882 Acc: 0.6911
# val Loss : 0.8853 Acc: 0.7683
# Epoch 13/49
# ----------
# train Loss : 1.1337 Acc: 0.6768
# val Loss : 1.0232 Acc: 0.7300
# Epoch 14/49
# ----------
# train Loss : 1.0890 Acc: 0.6841
# val Loss : 1.0031 Acc: 0.7267
# Epoch 15/49
# ----------
# train Loss : 1.0344 Acc: 0.7071
# val Loss : 0.8631 Acc: 0.7827
# Epoch 16/49
# ----------
# train Loss : 1.0611 Acc: 0.7003
# val Loss : 0.8406 Acc: 0.7613
# Epoch 17/49
# ----------
# train Loss : 1.0436 Acc: 0.7047
# val Loss : 0.9095 Acc: 0.7343
# Epoch 18/49
# ----------
# train Loss : 0.9914 Acc: 0.7154
# val Loss : 1.0428 Acc: 0.7313
# Epoch 19/49
# ----------
# train Loss : 0.9838 Acc: 0.7197
# val Loss : 0.8440 Acc: 0.7730
# Epoch 20/49
# ----------
# train Loss : 1.0179 Acc: 0.7100
# val Loss : 0.7613 Acc: 0.7833
# Epoch 21/49
# ----------
# train Loss : 0.9733 Acc: 0.7254
# val Loss : 0.9529 Acc: 0.7613
# Epoch 22/49
# ----------
# train Loss : 0.9778 Acc: 0.7211
# val Loss : 0.7791 Acc: 0.7877
# Epoch 23/49
# ----------
# train Loss : 0.9670 Acc: 0.7273
# val Loss : 0.8515 Acc: 0.7647
# Epoch 24/49
# ----------
# train Loss : 0.9289 Acc: 0.7310
# val Loss : 0.9052 Acc: 0.7743
# Epoch 25/49
# ----------
# train Loss : 0.9765 Acc: 0.7260
# val Loss : 1.0311 Acc: 0.7403
# Epoch 26/49
# ----------
# train Loss : 0.9236 Acc: 0.7444
# val Loss : 0.9726 Acc: 0.7420
# Epoch 27/49
# ----------
# train Loss : 0.9273 Acc: 0.7394
# val Loss : 0.9648 Acc: 0.7477
# Epoch 28/49
# ----------
# train Loss : 0.9491 Acc: 0.7366
# val Loss : 0.9765 Acc: 0.7667
# Epoch 29/49
# ----------
# train Loss : 0.8580 Acc: 0.7533
# val Loss : 0.9391 Acc: 0.7497
# Epoch 30/49
# ----------
# train Loss : 0.9315 Acc: 0.7362
# val Loss : 0.9031 Acc: 0.7900
# Epoch 31/49
# ----------
# train Loss : 0.9181 Acc: 0.7459
# val Loss : 0.7804 Acc: 0.7917
# Epoch 32/49
# ----------
# train Loss : 0.9184 Acc: 0.7484
# val Loss : 0.8297 Acc: 0.7933
# Epoch 33/49
# ----------
# train Loss : 0.8985 Acc: 0.7510
# val Loss : 1.0974 Acc: 0.7087
# Epoch 34/49
# ----------
# train Loss : 0.9083 Acc: 0.7454
# val Loss : 0.9063 Acc: 0.7877
# Epoch 35/49
# ----------
# train Loss : 0.8226 Acc: 0.7634
# val Loss : 0.7794 Acc: 0.7993
# Epoch 36/49
# ----------
# train Loss : 0.8705 Acc: 0.7570
# val Loss : 0.7771 Acc: 0.7983
# Epoch 37/49
# ----------
# train Loss : 0.9112 Acc: 0.7493
# val Loss : 0.9000 Acc: 0.7903
# Epoch 38/49
# ----------
# train Loss : 0.8678 Acc: 0.7619
# val Loss : 1.0256 Acc: 0.7510
# Epoch 39/49
# ----------
# train Loss : 0.8482 Acc: 0.7646
# val Loss : 0.8564 Acc: 0.7990
# Epoch 40/49
# ----------
# train Loss : 0.8804 Acc: 0.7530
# val Loss : 1.3157 Acc: 0.7947
# Epoch 41/49
# ----------
# train Loss : 0.8577 Acc: 0.7612
# val Loss : 0.8313 Acc: 0.8003
# Epoch 42/49
# ----------
# train Loss : 0.8561 Acc: 0.7620
# val Loss : 0.7970 Acc: 0.8140
# Epoch 43/49
# ----------
# train Loss : 0.8463 Acc: 0.7644
# val Loss : 0.9425 Acc: 0.7917
# Epoch 44/49
# ----------
# train Loss : 0.8499 Acc: 0.7684
# val Loss : 0.9429 Acc: 0.7880
# Epoch 45/49
# ----------
# train Loss : 0.8502 Acc: 0.7627
# val Loss : 0.9101 Acc: 0.8030
# Epoch 46/49
# ----------
# train Loss : 0.8167 Acc: 0.7697
# val Loss : 0.8379 Acc: 0.8160
# Epoch 47/49
# ----------
# train Loss : 0.8725 Acc: 0.7624
# val Loss : 0.7854 Acc: 0.7950
# Epoch 48/49
# ----------
# train Loss : 0.8209 Acc: 0.7730
# val Loss : 0.8682 Acc: 0.7780
# Epoch 49/49
# ----------
# train Loss : 0.9045 Acc: 0.7559
# val Loss : 1.0364 Acc: 0.7660

# %%
train_accs_1 = [x.cpu() for x in train_accs]
val_accs_1 = [x.cpu() for x in val_accs]

# %%
# Plotting the metrics
plt.figure(figsize=(12, 4))

# Plotting loss
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# Plotting accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accs_1, label="Train Accuracy")
plt.plot(val_accs_1, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %% [markdown]
# # Accuracy of Validation Data

# %%
model = WasteClassificationModel()
checkpoint = torch.load("models/train_loss_best.pt")
model.to(device)
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

data_size = len(image_datasets["val"])
y_preds = []
y_true = []

for idx, data in enumerate(data_loaders["val"]):
    inputs, labels = data["image"].to(device), data["label"].to(device)

    outputs = model(inputs)
    _, predictions = torch.max(outputs, 1)
    y_preds.extend(predictions.cpu().numpy().tolist())
    y_true.extend(labels.cpu().numpy().tolist())

print("\n-------Classification Report-------\n")
print(classification_report(y_true, y_preds, target_names=class_names))
cm = confusion_matrix(y_true, y_preds)
cm_disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(16, 14))
cm_disp.plot(ax=ax)
# Out:
# C:\Users\minhnguyen\AppData\Local\Temp\ipykernel_32880\1124581859.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("models/train_loss_best.pt")
# -------Classification Report-------
#
#                             precision    recall  f1-score   support
#
#               aerosol_cans       0.89      0.92      0.91       100
#         aluminum_food_cans       0.62      0.41      0.49       100
#         aluminum_soda_cans       0.87      0.88      0.88       100
#            cardboard_boxes       0.56      0.85      0.68       100
#        cardboard_packaging       0.75      0.36      0.49       100
#                   clothing       0.99      0.76      0.86       100
#             coffee_grounds       0.96      0.97      0.97       100
# disposable_plastic_cutlery       0.86      0.91      0.88       100
#                  eggshells       0.87      0.97      0.92       100
#                 food_waste       0.95      0.83      0.89       100
#     glass_beverage_bottles       0.84      0.88      0.86       100
#  glass_cosmetic_containers       0.84      0.94      0.89       100
#            glass_food_jars       0.93      0.84      0.88       100
#                  magazines       0.98      0.84      0.90       100
#                  newspaper       0.79      0.64      0.71       100
#               office_paper       0.62      0.77      0.69       100
#                 paper_cups       0.78      0.84      0.81       100
#           plastic_cup_lids       0.82      0.84      0.83       100
#  plastic_detergent_bottles       0.91      0.87      0.89       100
#    plastic_food_containers       0.79      0.84      0.82       100
#      plastic_shopping_bags       0.85      0.86      0.86       100
#       plastic_soda_bottles       0.79      0.79      0.79       100
#             plastic_straws       0.96      0.86      0.91       100
#         plastic_trash_bags       0.94      0.82      0.88       100
#      plastic_water_bottles       0.75      0.89      0.82       100
#                      shoes       0.69      0.94      0.79       100
#            steel_food_cans       0.61      0.71      0.66       100
#             styrofoam_cups       0.89      0.82      0.85       100
#  styrofoam_food_containers       0.92      0.78      0.84       100
#                   tea_bags       0.75      0.85      0.80       100
#
#                   accuracy                           0.82      3000
#                  macro avg       0.83      0.82      0.81      3000
#               weighted avg       0.83      0.82      0.81      3000

# %% [markdown]
# # Prediction on Sample Test Data

# %%
test_batch = next(iter(data_loaders["test"]))
inputs, labels = test_batch["image"].to(device), test_batch["label"].to(device)
outputs = model(inputs)
_, predictions = torch.max(outputs.data, 1)


fig = plt.figure("Test Batch", figsize=(batch_size, batch_size))
mean = np.array([0.5, 0.5, 0.5])
std = np.array([0.5, 0.5, 0.5])
# loop over the batch size
for i in range(len(predictions)):
    # create a subplot with 4x4
    ax = plt.subplot(8, 2, i + 1)
    # grab the image, convert it from channels first ordering to
    # channels last ordering, and scale the raw pixel intensities
    # to the range [0, 255]
    image = inputs[i].cpu().numpy()
    image = image.transpose((1, 2, 0))
    image = std * image + mean
    image = image.astype("uint8")
    # grab the label id and get the label from the classes list
    idx = labels[i]
    true_label = class_names[idx]
    predicted_label = class_names[predictions[i]]
    # show the image along with the label
    plt.imshow(image)
    title_label = "Y True : {} Y Predict : {}".format(true_label, predicted_label)
    plt.title(title_label)
    plt.axis("off")
# show the plot
plt.tight_layout()
plt.show()
